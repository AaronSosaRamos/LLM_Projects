# %% [markdown]
# #Smolagents Fundamentals
# Made by: Wilfredo Aaron Sosa Ramos

# %% [markdown]
# ##1. Basic Agents

# %%
# !pip install -q smolagents
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.4/320.4 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 67.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 62.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 51.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers -q

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=HfApiModel())

agent.run("How many seconds would it take for a leopard at full speed to run through Pont des Arts?")
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ How many seconds would it take for a leopard at full speed to run through Pont des Arts?                        │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 0 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ...

# %%
from google.colab import userdata
import os

os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')

# %% [markdown]
# ##2. Image Generation

# %%
from smolagents import load_tool, CodeAgent

image_generation_tool = Tool.from_space(
    "black-forest-labs/FLUX.1-schnell",
    name="image_generator",
    description="Generate an image from a prompt"
)

image_generation_tool("A sunny beach")

# %%
from smolagents import CodeAgent, HfApiModel

model = HfApiModel("Qwen/Qwen2.5-Coder-32B-Instruct")
agent = CodeAgent(tools=[image_generation_tool], model=model)

agent.run(
    "Improve this prompt, then generate an image of it.", prompt='A rabbit wearing a space suit'
)

# %%
# !pip install -q gradio_client

# %%
from gradio_client import Client

client = Client("black-forest-labs/FLUX.1-schnell")
result = client.predict(
		prompt="Create an image of a Capybara jumping in a mountain with snow",
		seed=0,
		randomize_seed=True,
		width=1024,
		height=1024,
		num_inference_steps=4,
		api_name="/infer"
)
print(result)
# Out:
# Loaded as API: https://black-forest-labs-flux-1-schnell.hf.space ✔
# ('/tmp/gradio/c7abe11c63512f10fb166f11c8957fa8158839ccf41b50bed8fca89f489a5481/image.webp', 1294186212)

# %%
# !pip install pillow

# %%
from PIL import Image as PILImage
import io
from IPython.display import Image as IPythonImage, display

image_path = '/tmp/gradio/c7abe11c63512f10fb166f11c8957fa8158839ccf41b50bed8fca89f489a5481/image.webp'

# Open the image using PIL
img = PILImage.open(image_path)

# Display the image using IPython.display.display
# This uses a buffer to avoid format issues
with io.BytesIO() as buf:
    img.save(buf, 'PNG')  # Save as PNG to the buffer
    buf.seek(0)  # Reset buffer position
    display(IPythonImage(data=buf.read(), format='PNG'))  # Display from buffer data

# %% [markdown]
# ##3. Custom Tools

# %%
# %%writefile my_tool.py
from smolagents import Tool

class HFModelDownloadsTool(Tool):
    name = "model_download_counter"
    description = """
    This is a tool that returns the most downloaded model of a given task on the Hugging Face Hub.
    It returns the name of the checkpoint."""
    inputs = {
        "task": {
            "type": "string",
            "description": "the task category (such as text-classification, depth-estimation, etc)",
        }
    }
    output_type = "string"

    def forward(self, task: str):
        from huggingface_hub import list_models

        model = next(iter(list_models(filter=task, sort="downloads", direction=-1)))
        return model.id

model_downloads_tool = HFModelDownloadsTool()
# Out:
# Writing my_tool.py

# %%
from my_tool import HFModelDownloadsTool
import os

model_downloads_tool = HFModelDownloadsTool()
model_downloads_tool.push_to_hub("WilAI/hf-model-downloads", token=os.environ['HF_TOKEN'])
# Out:
# README.md:   0%|          | 0.00/253 [00:00<?, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# /tmp/tmp6n9_iij7
# from smolagents.tools import Tool
#
# import huggingface_hub
#
#
#
# class HFModelDownloadsTool(Tool):
#
#     name = "model_download_counter"
#
#     description = """
#
#     This is a tool that returns the most downloaded model of a given task on the Hugging Face Hub.
#
#     It returns the name of the checkpoint."""
#
#     inputs = {'task': {'type': 'string', 'description': 'the task category (such as text-classification, depth-estimation, etc)'}}
#
#     output_type = "string"
#
#
#
#     def forward(self, task: str):
#
#         from huggingface_hub import list_models
#
#
#
#         model = next(iter(list_models(filter=task, sort="downloads", direction=-1)))
#
#         return model.id
#
#
#
#
#
# ...

# %%
from smolagents import load_tool, CodeAgent

model_download_tool = load_tool(
    "WilAI/hf-model-downloads",
    trust_remote_code=True
)
# Out:
# tool.py:   0%|          | 0.00/726 [00:00<?, ?B/s]
# TOOLCODE:
#  from smolagents.tools import Tool
# import huggingface_hub
#
# class HFModelDownloadsTool(Tool):
#     name = "model_download_counter"
#     description = """
#     This is a tool that returns the most downloaded model of a given task on the Hugging Face Hub.
#     It returns the name of the checkpoint."""
#     inputs = {'task': {'type': 'string', 'description': 'the task category (such as text-classification, depth-estimation, etc)'}}
#     output_type = "string"
#
#     def forward(self, task: str):
#         from huggingface_hub import list_models
#
#         model = next(iter(list_models(filter=task, sort="downloads", direction=-1)))
#         return model.id
#
#
#     def __init__(self, *args, **kwargs):
#         self.is_initialized = False

# %%
from smolagents import HfApiModel

model = HfApiModel("Qwen/Qwen2.5-Coder-32B-Instruct")

agent = CodeAgent(tools=[], model=model, add_base_tools=True)
agent.toolbox.add_tool(model_download_tool)

# %%
agent.run(
    "Can you give me the name of the model that has the most downloads in the 'text-to-video' task on the Hugging Face Hub but reverse the letters?"
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Can you give me the name of the model that has the most downloads in the 'text-to-video' task on the Hugging    │
# │ Face Hub but reverse the letters?                                                                               │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 0 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─ Executing this code: ──────────────────────────────────────────────────────────────────────────────────────────╮
# ...

# %% [markdown]
# ##4. Tools from LangChain

# %%
# !pip install -q langchain langchain_core langchain_community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 2.4 MB/s eta 0:00:00

# %%
# !pip install -q google-search-results
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
import os
from google.colab import userdata

os.environ['SERPAPI_API_KEY'] = userdata.get('SERPAPI_API_KEY')

# %%
from langchain.agents import load_tools

search_tool = Tool.from_langchain(load_tools(["serpapi"])[0])

model = HfApiModel("Qwen/Qwen2.5-Coder-32B-Instruct")
agent = CodeAgent(tools=[search_tool], model=model)

agent.run("How many more blocks (also denoted as layers) are in BERT base encoder compared to the encoder from the architecture proposed in Attention is All You Need?")

# %% [markdown]
# ##5. Collection of tools

# %%
from transformers import ToolCollection, CodeAgent

image_tool_collection = ToolCollection(
    collection_slug="huggingface-tools/diffusion-tools-6630bb19a942c2306a2cdb6f",
    token=userdata.get('HF_TOKEN')
)
agent = CodeAgent(tools=[*image_tool_collection.tools], model=model, add_base_tools=True)

agent.run("Please draw me a picture of a famous Capybara.")

# %% [markdown]
# ##6. LiteLLM Model

# %%
import os
from google.colab import userdata

os.environ['GEMINI_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
from smolagents import CodeAgent, LiteLLMModel
model = LiteLLMModel("gemini/gemini-2.0-flash-exp")

agent = CodeAgent(tools=[], model=model)

agent.run(
    "How can I build the DFS algorithm of graphs in Python, Java and C++?",
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ How can I build the DFS algorithm of graphs in Python, Java and C++?                                            │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash-exp ────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 0 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─ Executing this code: ──────────────────────────────────────────────────────────────────────────────────────────╮
# │   1 python_dfs = search(query="Python DFS algorithm implementation")                                            │
# ...
