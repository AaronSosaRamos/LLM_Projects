# %% [markdown]
# #Building Sequential Tasks with LangChain and Google GenAI
# Made by: Wilfredo Aaron Sosa Ramos (AI Lab Manager at RealityAI Labs)

# %%
# !pip install -q langchain langchain_community langchain_core langchain_google_genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.4 MB/s eta 0:00:00

# %%
# !pip install -q rich

# %%
import os
from google.colab import userdata

if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# %% [markdown]
# ##1. The Pipe Operator (|)

# %%
# Setup
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# Initialize the model
model = ChatGoogleGenerativeAI(model="gemini-1.5-flash")

# Define a prompt to generate Python code
code_prompt = ChatPromptTemplate.from_template(
    "Write Python code for the following task: {task}"
)

# Create a chain for code generation
code_chain = code_prompt | model | StrOutputParser()

# Invoke the chain
result = code_chain.invoke({"task": "read a CSV file and calculate the mean of a column"})
print("Generated Code:\n", result)
# Out:
# Generated Code:
#  Several methods exist for calculating the mean of a column in a CSV file using Python. Here are two common approaches, one using the `csv` module and another using the more efficient `pandas` library:
#
#
# **Method 1: Using the `csv` module (for smaller files)**
#
# This method is suitable for smaller CSV files where loading the entire file into memory isn't a concern.
#
# ```python
# import csv
#
# def calculate_column_mean(filepath, column_name):
#     """Calculates the mean of a specified column in a CSV file.
#
#     Args:
#         filepath: Path to the CSV file.
#         column_name: The name of the column to calculate the mean for.
#
#     Returns:
#         The mean of the column, or None if the column is not found or contains non-numeric values.
#     """
#     try:
#         with open(filepath, 'r', newline='') as csvfile:
#             reader = csv.DictReader(csvfile)  # Use DictReader for easier column access
#             column_data = []
#             for row in reader:
#                 try:
#                     value = float(row[column_name]) #convert to float to handle potential errors
#                     column_data.append(value)
#                 except (KeyError, ValueError):
#                     print(f"Warning: Skipping non-numeric value or missing column in row: {row}")
#                     continue #skip rows with errors
#
#             if not column_data:
#                 return None  # Handle empty column
#             return sum(column_data) / len(column_data)
#     except FileNotFoundError:
#         print(f"Error: File not found at {filepath}")
#         return None
#
#
# # Example usage:
# filepath = 'data.csv'  # Replace with your CSV file path
# column_name = 'Value'  # Replace with your column name
# mean = calculate_column_mean(filepath, column_name)
#
# if mean is not None:
#     print(f"The mean of the '{column_name}' column is: {mean}")
#
# ```
#
# **Method 2: Using the `pandas` library (for larger files and more features)**
#
# Pandas is a powerful library for data manipulation and analysis. It's significantly more efficient for larger CSV files and offers many other useful features.
#
# ```python
# import pandas as pd
#
# def calculate_column_mean_pandas(filepath, column_name):
#     """Calculates the mean of a specified column in a CSV file using pandas.
#
#     Args:
#         filepath: Path to the CSV file.
#         column_name: The name of the column to calculate the mean for.
#
#     Returns:
#         The mean of the column, or None if the column is not found or contains non-numeric values.
#     """
#     try:
#         df = pd.read_csv(filepath)
#         if column_name not in df.columns:
#             print(f"Error: Column '{column_name}' not found in CSV file.")
#             return None
#         return df[column_name].mean()
#     except FileNotFoundError:
#         print(f"Error: File not found at {filepath}")
#         return None
#     except pd.errors.EmptyDataError:
#         print(f"Error: CSV file is empty")
#         return None
#     except pd.errors.ParserError:
#         print(f"Error: Could not parse CSV file")
#         return None
#
#
# # Example usage:
# filepath = 'data.csv'  # Replace with your CSV file path
# column_name = 'Value'  # Replace with your column name
# mean = calculate_column_mean_pandas(filepath, column_name)
#
# if mean is not None:
#     print(f"The mean of the '{column_name}' column is: {mean}")
#
# ```
#
# Remember to install pandas if you haven't already:  `pip install pandas`
#
# The pandas method is generally preferred for its efficiency, especially with larger datasets, and its robust error handling.  The `csv` method is a good option if you want to avoid external dependencies.  Choose the method that best suits your needs and the size of your data.  Both include improved error handling to gracefully manage file not found, empty files, and non-numeric data.

# %%
from rich.console import Console
from rich.markdown import Markdown

console = Console()

def print_md(result):
  markdown = Markdown(result)
  console.print(markdown)

# %%
print_md(result)
# Out:
# Several methods exist for calculating the mean of a column in a CSV file using Python. Here are two common
# approaches, one using the csv module and another using the more efficient pandas library:
#
# Method 1: Using the csv module (for smaller files)
#
# This method is suitable for smaller CSV files where loading the entire file into memory isn't a concern.
#
#
#  import csv
#
#  def calculate_column_mean(filepath, column_name):
#      """Calculates the mean of a specified column in a CSV file.
#
#      Args:
#          filepath: Path to the CSV file.
#          column_name: The name of the column to calculate the mean for.
#
#      Returns:
#          The mean of the column, or None if the column is not found or contains non-numeric values.
#      """
#      try:
#          with open(filepath, 'r', newline='') as csvfile:
#              reader = csv.DictReader(csvfile)  # Use DictReader for easier column access
#              column_data = []
#              for row in reader:
#                  try:
#                      value = float(row[column_name]) #convert to float to handle potential errors
#                      column_data.append(value)
#                  except (KeyError, ValueError):
#                      print(f"Warning: Skipping non-numeric value or missing column in row: {row}")
#                      continue #skip rows with errors
#
#              if not column_data:
#                  return None  # Handle empty column
#              return sum(column_data) / len(column_data)
#      except FileNotFoundError:
#          print(f"Error: File not found at {filepath}")
#          return None
#
#
#  # Example usage:
#  filepath = 'data.csv'  # Replace with your CSV file path
#  column_name = 'Value'  # Replace with your column name
#  mean = calculate_column_mean(filepath, column_name)
#
#  if mean is not None:
#      print(f"The mean of the '{column_name}' column is: {mean}")
#
#
# Method 2: Using the pandas library (for larger files and more features)
#
# Pandas is a powerful library for data manipulation and analysis. It's significantly more efficient for larger CSV
# files and offers many other useful features.
#
#
#  import pandas as pd
#
#  def calculate_column_mean_pandas(filepath, column_name):
#      """Calculates the mean of a specified column in a CSV file using pandas.
#
#      Args:
#          filepath: Path to the CSV file.
#          column_name: The name of the column to calculate the mean for.
#
#      Returns:
#          The mean of the column, or None if the column is not found or contains non-numeric values.
#      """
#      try:
#          df = pd.read_csv(filepath)
#          if column_name not in df.columns:
#              print(f"Error: Column '{column_name}' not found in CSV file.")
#              return None
#          return df[column_name].mean()
#      except FileNotFoundError:
#          print(f"Error: File not found at {filepath}")
#          return None
#      except pd.errors.EmptyDataError:
#          print(f"Error: CSV file is empty")
#          return None
#      except pd.errors.ParserError:
#          print(f"Error: Could not parse CSV file")
#          return None
#
#
#  # Example usage:
#  filepath = 'data.csv'  # Replace with your CSV file path
#  column_name = 'Value'  # Replace with your column name
#  mean = calculate_column_mean_pandas(filepath, column_name)
#
#  if mean is not None:
#      print(f"The mean of the '{column_name}' column is: {mean}")
#
#
# Remember to install pandas if you haven't already:  pip install pandas
#
# The pandas method is generally preferred for its efficiency, especially with larger datasets, and its robust error
# handling.  The csv method is a good option if you want to avoid external dependencies.  Choose the method that best
# suits your needs and the size of your data.  Both include improved error handling to gracefully manage file not
# found, empty files, and non-numeric data.

# %% [markdown]
# ##2. Coercion for Code Analysis

# %%
# Define a prompt for analyzing code
analysis_prompt = ChatPromptTemplate.from_template(
    "Analyze the following Python code and provide suggestions for optimization: {code}"
)

# Create a composed chain using coercion
composed_chain = {"code": code_chain} | analysis_prompt | model | StrOutputParser()

# Invoke the chain
result_analysis = composed_chain.invoke(
    {"task": "read a CSV file and calculate the mean of a column"}
)
print("Code Analysis:\n", result_analysis)

# Adding lambda for custom coercion
composed_chain_with_lambda = (
    code_chain
    | (lambda input: {"code": input})
    | analysis_prompt
    | model
    | StrOutputParser()
)

result_lambda = composed_chain_with_lambda.invoke(
    {"task": "read a CSV file and calculate the mean of a column"}
)
print("Code Analysis with Lambda:\n", result_lambda)
# Out:
# Code Analysis:
#  The analysis shows that the Pandas method is significantly more efficient, especially for larger files.  The `csv` module method is inherently slower because it iterates row by row and performs manual type conversion and error handling. Pandas leverages optimized vectorized operations.  However, both methods can be improved.
#
#
# **Improvements for the `csv` module method:**
#
# 1. **Error Handling:** The `try-except` block inside the loop is inefficient.  It's better to filter for numeric values *after* reading the entire column. This avoids repeated exception handling.
#
# 2. **Type hinting:** Adding type hints improves code readability and maintainability.
#
# 3. **More informative error messages:**  The error messages could provide more context (e.g., the row number).
#
#
# ```python
# import csv
# from typing import List, Union
#
# def calculate_column_mean_csv_improved(filepath: str, column_name: str) -> Union[float, None]:
#     """Calculates the mean of a specified column in a CSV file (improved)."""
#     try:
#         with open(filepath, 'r', newline='') as csvfile:
#             reader = csv.DictReader(csvfile)
#             column_data: List[str] = [row.get(column_name) for row in reader]
#
#         if not column_data:
#             return None
#
#         numeric_data = [float(x) for x in column_data if x.replace('.', '', 1).isdigit()] #Improved numeric check
#
#         if not numeric_data:
#             print(f"Error: Column '{column_name}' contains no numeric values.")
#             return None
#
#         return sum(numeric_data) / len(numeric_data)
#
#     except FileNotFoundError:
#         print(f"Error: File '{filepath}' not found.")
#         return None
#     except ValueError as e:
#         print(f"Error: Invalid data in column '{column_name}'. Details: {e}")
#         return None
#     except Exception as e:
#         print(f"An unexpected error occurred: {e}")
#         return None
#
# ```
#
# **Improvements for the Pandas method:**
#
# 1. **Error Handling:** While Pandas handles many errors gracefully, explicitly checking for the column's existence before attempting to calculate the mean makes the code more robust and readable.
#
# 2. **Type hinting:**  Similar to the `csv` method.
#
# 3. **More efficient data type handling:** Pandas can infer data types automatically.  However, for very large files, explicitly specifying the data type of the column during `read_csv` can improve performance if you know the data type in advance (e.g., `dtype={'Value': float}`).
#
#
# ```python
# import pandas as pd
# from typing import Union
#
# def calculate_column_mean_pandas_improved(filepath: str, column_name: str) -> Union[float, None]:
#     """Calculates the mean of a specified column in a CSV file using pandas (improved)."""
#     try:
#         df = pd.read_csv(filepath)
#         if column_name not in df.columns:
#             print(f"Error: Column '{column_name}' not found in CSV file.")
#             return None
#         #Check for numeric data before mean calculation
#         if not pd.api.types.is_numeric_dtype(df[column_name]):
#             print(f"Error: Column '{column_name}' is not numeric.")
#             return None
#         return df[column_name].mean()
#     except FileNotFoundError:
#         print(f"Error: File '{filepath}' not found.")
#         return None
#     except Exception as e:
#         print(f"An unexpected error occurred: {e}")
#         return None
# ```
#
# **Conclusion:**
#
# For most cases, especially with larger datasets, the improved Pandas method remains the superior choice due to its inherent efficiency.  The improved `csv` method offers a viable alternative only for very small files where the overhead of importing and using Pandas is undesirable.  Always prioritize the Pandas approach unless you have a compelling reason to avoid external dependencies.  Remember to handle potential errors and improve error messages for better code robustness.
#
# Code Analysis with Lambda:
#  The provided code examples are generally well-written and demonstrate different approaches to calculating the mean of a CSV column. Here's an analysis with optimization suggestions:
#
#
# **Method 1 (csv module):**
#
# * **Efficiency:** This method is the least efficient, especially for large files, as it reads the entire file into memory at once.  The list comprehension creates a list of all the values before calculating the mean.
# * **Error Handling:**  It handles `FileNotFoundError`, `KeyError`, and `ValueError`, which is good. However, it doesn't handle other potential errors like malformed CSV data.  The empty string handling is a bit awkward.
# * **Optimization:**  The primary optimization is to avoid loading the entire column into memory at once.  Instead, process the file line by line, accumulating the sum and count simultaneously.
#
# ```python
# import csv
#
# def calculate_column_mean_optimized1(filename, column_name):
#     try:
#         with open(filename, 'r', newline='') as csvfile:
#             reader = csv.DictReader(csvfile)
#             total = 0
#             count = 0
#             for row in reader:
#                 try:
#                     value = float(row[column_name])
#                     total += value
#                     count += 1
#                 except (ValueError, KeyError): # Combine error handling
#                     pass # Ignore rows with errors.  Consider logging these errors instead.
#             if count == 0:
#                 return None
#             return total / count
#     except FileNotFoundError:
#         print(f"Error: File '{filename}' not found.")
#         return None
#
# ```
#
# **Method 2 (pandas):**
#
# * **Efficiency:** This is generally the most efficient and robust method for larger datasets due to pandas' optimized vectorized operations.
# * **Error Handling:**  Excellent error handling, covering various pandas-specific exceptions.
# * **Optimization:** The code is already quite efficient.  One minor optimization could be to directly specify the `dtype` in `pd.read_csv` if the column type is known in advance to potentially speed up reading.  For example, if 'Value' is always numeric: `df = pd.read_csv(filename, dtype={'Value': np.float64})`
#
#
# **Method 3 (NumPy):**
#
# * **Efficiency:** NumPy is very efficient for numerical computations. However, the current implementation reads the entire file twice: once to get the header and once to get the data.
# * **Error Handling:** Similar to pandas, good error handling.
# * **Optimization:**  The biggest improvement is to read the file only once.  We can use `np.loadtxt` with the `skiprows` parameter instead of `np.genfromtxt`.  Also, using `np.fromstring` on the relevant column can further enhance speed.
#
# ```python
# import numpy as np
#
# def calculate_column_mean_optimized3(filename, column_name):
#     try:
#         with open(filename, 'r') as f:
#             header = f.readline().strip().split(',')
#             column_index = header.index(column_name)  #Directly find the index
#             data = np.loadtxt(f, delimiter=',', skiprows=0, dtype=float, missing_values='NaN', filling_values=np.nan, usecols=(column_index,))
#
#         clean_data = data[~np.isnan(data)]
#         if clean_data.size == 0:
#             return None
#         return np.mean(clean_data)
#
#     except FileNotFoundError:
#         print(f"Error: File '{filename}' not found.")
#         return None
#     except ValueError:
#         print("Error: Could not parse the CSV file.")
#         return None
#     except IndexError:
#         print(f"Error: Column '{column_name}' not found in the CSV file.")
#         return None
# ```
#
#
# **General Recommendations:**
#
# * **Logging:** Instead of just printing error messages, consider using a proper logging system (e.g., Python's `logging` module) for better error management, especially in production environments.
# * **Input Validation:** Add more robust input validation. Check that `filename` is a string and `column_name` is a string.
# * **Docstrings:** Ensure docstrings are clear and concise, specifying potential exceptions.
#
#
# In summary, for most cases, the optimized pandas method remains the best option due to its balance of efficiency, robustness, and ease of use. The optimized NumPy method offers the best speed for purely numerical data, whereas the optimized `csv` method is suitable for very small files or educational purposes.  Choose the method that best suits your needs and data characteristics. Remember to profile your code with larger datasets to determine the actual performance differences.

# %%
print_md(result_analysis)
# Out:
# The analysis shows that the Pandas method is significantly more efficient, especially for larger files.  The csv
# module method is inherently slower because it iterates row by row and performs manual type conversion and error
# handling. Pandas leverages optimized vectorized operations.  However, both methods can be improved.
#
# Improvements for the csv module method:
#
#  1 Error Handling: The try-except block inside the loop is inefficient.  It's better to filter for numeric values
#    after reading the entire column. This avoids repeated exception handling.
#  2 Type hinting: Adding type hints improves code readability and maintainability.
#  3 More informative error messages:  The error messages could provide more context (e.g., the row number).
#
#
#  import csv
#  from typing import List, Union
#
#  def calculate_column_mean_csv_improved(filepath: str, column_name: str) -> Union[float, None]:
#      """Calculates the mean of a specified column in a CSV file (improved)."""
#      try:
#          with open(filepath, 'r', newline='') as csvfile:
#              reader = csv.DictReader(csvfile)
#              column_data: List[str] = [row.get(column_name) for row in reader]
#
#          if not column_data:
#              return None
#
#          numeric_data = [float(x) for x in column_data if x.replace('.', '', 1).isdigit()] #Improved numeric check
#
#          if not numeric_data:
#              print(f"Error: Column '{column_name}' contains no numeric values.")
#              return None
#
#          return sum(numeric_data) / len(numeric_data)
#
#      except FileNotFoundError:
#          print(f"Error: File '{filepath}' not found.")
#          return None
#      except ValueError as e:
#          print(f"Error: Invalid data in column '{column_name}'. Details: {e}")
#          return None
#      except Exception as e:
#          print(f"An unexpected error occurred: {e}")
#          return None
#
#
# Improvements for the Pandas method:
#
#  1 Error Handling: While Pandas handles many errors gracefully, explicitly checking for the column's existence
#    before attempting to calculate the mean makes the code more robust and readable.
#  2 Type hinting:  Similar to the csv method.
#  3 More efficient data type handling: Pandas can infer data types automatically.  However, for very large files,
#    explicitly specifying the data type of the column during read_csv can improve performance if you know the data
#    type in advance (e.g., dtype={'Value': float}).
#
#
#  import pandas as pd
#  from typing import Union
#
#  def calculate_column_mean_pandas_improved(filepath: str, column_name: str) -> Union[float, None]:
#      """Calculates the mean of a specified column in a CSV file using pandas (improved)."""
#      try:
#          df = pd.read_csv(filepath)
#          if column_name not in df.columns:
#              print(f"Error: Column '{column_name}' not found in CSV file.")
#              return None
#          #Check for numeric data before mean calculation
#          if not pd.api.types.is_numeric_dtype(df[column_name]):
#              print(f"Error: Column '{column_name}' is not numeric.")
#              return None
#          return df[column_name].mean()
#      except FileNotFoundError:
#          print(f"Error: File '{filepath}' not found.")
#          return None
#      except Exception as e:
#          print(f"An unexpected error occurred: {e}")
#          return None
#
#
# Conclusion:
#
# For most cases, especially with larger datasets, the improved Pandas method remains the superior choice due to its
# inherent efficiency.  The improved csv method offers a viable alternative only for very small files where the
# overhead of importing and using Pandas is undesirable.  Always prioritize the Pandas approach unless you have a
# compelling reason to avoid external dependencies.  Remember to handle potential errors and improve error messages
# for better code robustness.

# %%
print_md(result_lambda)
# Out:
# The provided code examples are generally well-written and demonstrate different approaches to calculating the mean
# of a CSV column. Here's an analysis with optimization suggestions:
#
# Method 1 (csv module):
#
#  • Efficiency: This method is the least efficient, especially for large files, as it reads the entire file into
#    memory at once.  The list comprehension creates a list of all the values before calculating the mean.
#  • Error Handling:  It handles FileNotFoundError, KeyError, and ValueError, which is good. However, it doesn't
#    handle other potential errors like malformed CSV data.  The empty string handling is a bit awkward.
#  • Optimization:  The primary optimization is to avoid loading the entire column into memory at once.  Instead,
#    process the file line by line, accumulating the sum and count simultaneously.
#
#
#  import csv
#
#  def calculate_column_mean_optimized1(filename, column_name):
#      try:
#          with open(filename, 'r', newline='') as csvfile:
#              reader = csv.DictReader(csvfile)
#              total = 0
#              count = 0
#              for row in reader:
#                  try:
#                      value = float(row[column_name])
#                      total += value
#                      count += 1
#                  except (ValueError, KeyError): # Combine error handling
#                      pass # Ignore rows with errors.  Consider logging these errors instead.
#              if count == 0:
#                  return None
#              return total / count
#      except FileNotFoundError:
#          print(f"Error: File '{filename}' not found.")
#          return None
#
#
# Method 2 (pandas):
#
#  • Efficiency: This is generally the most efficient and robust method for larger datasets due to pandas' optimized
#    vectorized operations.
#  • Error Handling:  Excellent error handling, covering various pandas-specific exceptions.
#  • Optimization: The code is already quite efficient.  One minor optimization could be to directly specify the
#    dtype in pd.read_csv if the column type is known in advance to potentially speed up reading.  For example, if
#    'Value' is always numeric: df = pd.read_csv(filename, dtype={'Value': np.float64})
#
# Method 3 (NumPy):
#
#  • Efficiency: NumPy is very efficient for numerical computations. However, the current implementation reads the
#    entire file twice: once to get the header and once to get the data.
#  • Error Handling: Similar to pandas, good error handling.
#  • Optimization:  The biggest improvement is to read the file only once.  We can use np.loadtxt with the skiprows
#    parameter instead of np.genfromtxt.  Also, using np.fromstring on the relevant column can further enhance speed.
#
#
#  import numpy as np
#
#  def calculate_column_mean_optimized3(filename, column_name):
#      try:
#          with open(filename, 'r') as f:
#              header = f.readline().strip().split(',')
#              column_index = header.index(column_name)  #Directly find the index
#              data = np.loadtxt(f, delimiter=',', skiprows=0, dtype=float, missing_values='NaN',
#  filling_values=np.nan, usecols=(column_index,))
#
#          clean_data = data[~np.isnan(data)]
#          if clean_data.size == 0:
#              return None
#          return np.mean(clean_data)
#
#      except FileNotFoundError:
#          print(f"Error: File '{filename}' not found.")
#          return None
#      except ValueError:
#          print("Error: Could not parse the CSV file.")
#          return None
#      except IndexError:
#          print(f"Error: Column '{column_name}' not found in the CSV file.")
#          return None
#
#
# General Recommendations:
#
#  • Logging: Instead of just printing error messages, consider using a proper logging system (e.g., Python's logging
#    module) for better error management, especially in production environments.
#  • Input Validation: Add more robust input validation. Check that filename is a string and column_name is a string.
#  • Docstrings: Ensure docstrings are clear and concise, specifying potential exceptions.
#
# In summary, for most cases, the optimized pandas method remains the best option due to its balance of efficiency,
# robustness, and ease of use. The optimized NumPy method offers the best speed for purely numerical data, whereas
# the optimized csv method is suitable for very small files or educational purposes.  Choose the method that best
# suits your needs and data characteristics. Remember to profile your code with larger datasets to determine the
# actual performance differences.

# %% [markdown]
# ##3. The .pipe() Method for Optimization

# %%
from langchain_core.runnables import RunnableParallel

# Define a prompt for code optimization
optimization_prompt = ChatPromptTemplate.from_template(
    "Optimize the following Python code to improve performance and readability: {code}"
)

# Create a composed chain with the pipe method
composed_chain_with_pipe = (
    RunnableParallel({"code": code_chain})
    .pipe(optimization_prompt)
    .pipe(model)
    .pipe(StrOutputParser())
)

# Invoke the chain
result_pipe = composed_chain_with_pipe.invoke(
    {"task": "Create the Quicksort algorithm and use it in a ML algorithm"}
)
print("Optimized Code:\n", result_pipe)
# Out:
# Optimized Code:
#  ```python
# import random
# import heapq  # For efficient k-NN search
#
# def euclidean_distance(x1, x2):
#     """Calculates the Euclidean distance between two data points."""
#     return sum((a - b)**2 for a, b in zip(x1, x2))**0.5
#
#
# def k_nearest_neighbors(X_train, y_train, X_test, k):
#     """k-Nearest Neighbors algorithm using a heap for efficiency."""
#     y_pred = []
#     for test_point in X_test:
#         # Use a heap to efficiently find the k-nearest neighbors
#         distances = []
#         for train_point, label in zip(X_train, y_train):
#             dist = euclidean_distance(test_point, train_point)
#             if len(distances) < k:
#                 heapq.heappush(distances, (-dist, label)) #negate distance for min-heap
#             else:
#                 if -distances[0][0] > dist:
#                     heapq.heapreplace(distances, (-dist, label))
#
#         k_nearest = distances
#         labels = [label for _, label in k_nearest]
#         y_pred.append(max(set(labels), key=labels.count))
#     return y_pred
#
#
# # Example usage:
# # Generate some random training data
# X_train = [[random.uniform(0, 10) for _ in range(2)] for _ in range(1000)] # Increased data size for better comparison
# y_train = [random.randint(0, 1) for _ in range(1000)]  # Binary classification
#
# # Generate some test data
# X_test = [[random.uniform(0, 10) for _ in range(2)] for _ in range(200)] #Increased data size for better comparison
#
#
# # Run k-NN with unsorted data (using heap for efficiency)
# y_pred_unsorted = k_nearest_neighbors(X_train, y_train, X_test, k=5)
#
# print("Predictions with unsorted data (using heap):", y_pred_unsorted)
#
#
# #Illustrative use of scikit-learn (Recommended for real-world use)
# from sklearn.neighbors import KNeighborsClassifier
# knn = KNeighborsClassifier(n_neighbors=5)
# knn.fit(X_train, y_train)
# y_pred_sklearn = knn.predict(X_test)
# print("Predictions with scikit-learn:", y_pred_sklearn)
#
# ```
#
# **Key Improvements:**
#
# * **Removed Quicksort:**  The original code's use of Quicksort for pre-sorting was inefficient and unnecessary for k-NN.  The sorting overhead often outweighs any potential benefit.
# * **Efficient k-NN Search with Heap:** The improved code uses a min-heap (`heapq`) to efficiently track the k-nearest neighbors.  This avoids a full sort of all distances, making the k-NN search much faster, especially for larger datasets.  The heap maintains the k smallest distances encountered so far.
# * **Increased Data Size:** The example now uses larger datasets (1000 training points, 200 test points) to better illustrate the performance differences.  The original small dataset size masked the inefficiency of the quicksort approach.
# * **Scikit-learn Integration:** The code now includes a section demonstrating how to use the highly optimized `KNeighborsClassifier` from scikit-learn.  This is the recommended approach for real-world applications.  Scikit-learn uses optimized data structures and algorithms for efficient k-NN.
#
# This revised code provides a much more realistic and efficient implementation of k-NN, highlighting the importance of using appropriate data structures and established libraries for machine learning tasks.  The use of `heapq` significantly improves the performance of the k-NN search without the unnecessary overhead of sorting the entire training dataset.  Using `scikit-learn` is strongly advised for production-level code.

# %%
print_md(result_pipe)
# Out:
#
#  import random
#  import heapq  # For efficient k-NN search
#
#  def euclidean_distance(x1, x2):
#      """Calculates the Euclidean distance between two data points."""
#      return sum((a - b)**2 for a, b in zip(x1, x2))**0.5
#
#
#  def k_nearest_neighbors(X_train, y_train, X_test, k):
#      """k-Nearest Neighbors algorithm using a heap for efficiency."""
#      y_pred = []
#      for test_point in X_test:
#          # Use a heap to efficiently find the k-nearest neighbors
#          distances = []
#          for train_point, label in zip(X_train, y_train):
#              dist = euclidean_distance(test_point, train_point)
#              if len(distances) < k:
#                  heapq.heappush(distances, (-dist, label)) #negate distance for min-heap
#              else:
#                  if -distances[0][0] > dist:
#                      heapq.heapreplace(distances, (-dist, label))
#
#          k_nearest = distances
#          labels = [label for _, label in k_nearest]
#          y_pred.append(max(set(labels), key=labels.count))
#      return y_pred
#
#
#  # Example usage:
#  # Generate some random training data
#  X_train = [[random.uniform(0, 10) for _ in range(2)] for _ in range(1000)] # Increased data size for better
#  comparison
#  y_train = [random.randint(0, 1) for _ in range(1000)]  # Binary classification
#
#  # Generate some test data
#  X_test = [[random.uniform(0, 10) for _ in range(2)] for _ in range(200)] #Increased data size for better comparis
#
#
#  # Run k-NN with unsorted data (using heap for efficiency)
#  y_pred_unsorted = k_nearest_neighbors(X_train, y_train, X_test, k=5)
#
#  print("Predictions with unsorted data (using heap):", y_pred_unsorted)
#
#
#  #Illustrative use of scikit-learn (Recommended for real-world use)
#  from sklearn.neighbors import KNeighborsClassifier
#  knn = KNeighborsClassifier(n_neighbors=5)
#  knn.fit(X_train, y_train)
#  y_pred_sklearn = knn.predict(X_test)
#  print("Predictions with scikit-learn:", y_pred_sklearn)
#
#
# Key Improvements:
#
#  • Removed Quicksort:  The original code's use of Quicksort for pre-sorting was inefficient and unnecessary for
#    k-NN.  The sorting overhead often outweighs any potential benefit.
#  • Efficient k-NN Search with Heap: The improved code uses a min-heap (heapq) to efficiently track the k-nearest
#    neighbors.  This avoids a full sort of all distances, making the k-NN search much faster, especially for larger
#    datasets.  The heap maintains the k smallest distances encountered so far.
#  • Increased Data Size: The example now uses larger datasets (1000 training points, 200 test points) to better
#    illustrate the performance differences.  The original small dataset size masked the inefficiency of the
#    quicksort approach.
#  • Scikit-learn Integration: The code now includes a section demonstrating how to use the highly optimized
#    KNeighborsClassifier from scikit-learn.  This is the recommended approach for real-world applications.
#    Scikit-learn uses optimized data structures and algorithms for efficient k-NN.
#
# This revised code provides a much more realistic and efficient implementation of k-NN, highlighting the importance
# of using appropriate data structures and established libraries for machine learning tasks.  The use of heapq
# significantly improves the performance of the k-NN search without the unnecessary overhead of sorting the entire
# training dataset.  Using scikit-learn is strongly advised for production-level code.
